# %% [markdown]
# **Importing & Processing Data**

# %%
import pandas as pd
df = pd.read_csv("/content/Census_data.csv", skiprows=4)
#pandas can't read first 4 rows

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
df.duplicated().sum() #To check duplicate entries
# Out:
# 0

# %%
df.isna().sum().any #To check Null values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2019                1
# 2020                1
# 2021                1
# 2022                1
# Unnamed: 67       266
# Length: 68, dtype: int64>

# %%
df = df.fillna(method="ffill")
df #Filed null values with 'ffill'
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df.isna().sum().any #Verifying no. of Null values
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                0
#                  ...
# 2019                0
# 2020                0
# 2021                0
# 2022                0
# Unnamed: 67       266
# Length: 68, dtype: int64>

# %% [markdown]
# Checking & Removing **Redundancy**

# %%
df['Indicator Code'].unique()
# Out:
# array(['SP.POP.TOTL'], dtype=object)

# %%
df['Indicator Name'].unique()
# Out:
# array(['Population, total'], dtype=object)

# %%
df.drop(['Indicator Name', 'Indicator Code'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', 'Unnamed: 67'],
#       dtype='object')

# %%
cols = [ '1960', '1961', '1962', '1963', '1964', '1965', '1966',
       '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
       '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
       '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
       '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
       '2021', '2022' ]

# %% [markdown]
# **Histograms**

# %%
#Plottig histogram for each Year
import matplotlib.pyplot as plt

for i in cols:
  fig=plt.figure(figsize=(16,9))
  plt.hist(df[i], bins=10)
  plt.xlabel(i)
  plt.show()

# %% [markdown]
# **Bar Graphs**

# %%
#World Population
years = df.columns[2:]
years
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %%
total_values = df[years].sum()
total_values
# Out:
# 1960           3.140744e+10
# 1961           3.184280e+10
# 1962           3.242650e+10
# 1963           3.314556e+10
# 1964           3.387074e+10
#                    ...
# 2019           8.503568e+10
# 2020           8.600015e+10
# 2021           8.687593e+10
# 2022           8.766759e+10
# Unnamed: 67    0.000000e+00
# Length: 64, dtype: float64

# %%
plt.figure(figsize=(30,30))
plt.barh(years, total_values, label='Total Population of all Countries')
plt.xlabel('Total Values')
plt.title('Total Population in the Year')
plt.ylabel('Year')
plt.legend()

# %% [markdown]
# **Importing & Merging Another CSV**

# %%
  df_1 = pd.read_csv('/content/Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_6298256.csv')
  df_1 #Importing Another CSV
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# ...

# %%
merged = pd.merge(df, df_1, on='Country Code')
merged
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54608.0      55811.0
# 1    Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                    Afghanistan          AFG    8622466.0    8790140.0
# 3     Africa Western and Central          AFW   97256290.0   99314028.0
# 4                         Angola          AGO    5357195.0    5441333.0
# ..                           ...          ...          ...          ...
# 260                       Kosovo          XKX     947000.0     966000.0
# 261                  Yemen, Rep.          YEM    5542459.0    5646668.0
# 262                 South Africa          ZAF   16520441.0   16989464.0
# 263                       Zambia          ZMB    3119430.0    3219451.0
# 264                     Zimbabwe          ZWE    3806310.0    3925952.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
merged.columns
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', 'Unnamed: 67', 'Region', 'IncomeGroup',
#        'SpecialNotes', 'TableName', 'Unnamed: 5'],
#       dtype='object')

# %% [markdown]
# **Data Cleaning**

# %%
merged['Unnamed: 5']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 260   NaN
# 261   NaN
# 262   NaN
# 263   NaN
# 264   NaN
# Name: Unnamed: 5, Length: 265, dtype: float64

# %%
merged['Unnamed: 5'].unique()
# Out:
# array([nan])

# %%
merged['Unnamed: 67']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 260   NaN
# 261   NaN
# 262   NaN
# 263   NaN
# 264   NaN
# Name: Unnamed: 67, Length: 265, dtype: float64

# %%
merged['Unnamed: 67'].unique()
# Out:
# array([nan])

# %%
merged['Country Name']
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 260                         Kosovo
# 261                    Yemen, Rep.
# 262                   South Africa
# 263                         Zambia
# 264                       Zimbabwe
# Name: Country Name, Length: 265, dtype: object

# %%
merged['TableName']
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 260                         Kosovo
# 261                    Yemen, Rep.
# 262                   South Africa
# 263                         Zambia
# 264                       Zimbabwe
# Name: TableName, Length: 265, dtype: object

# %%
duplicate = merged['Country Name'].compare(merged['TableName'])
duplicate
# Out:
#                                                   self  \
# 41                                       Cote d'Ivoire
# 51                                             Curacao
# 218                              Sao Tome and Principe
# 229         East Asia & Pacific (IDA & IBRD countries)
# 230       Europe & Central Asia (IDA & IBRD countries)
# 235  Latin America & the Caribbean (IDA & IBRD coun...
# 237  Middle East & North Africa (IDA & IBRD countries)
# 240          Sub-Saharan Africa (IDA & IBRD countries)
# 243                                            Turkiye
#
#                                        other
# 41                             Côte d'Ivoire
# 51                                   Curaçao
# 218                    São Tomé and Principe
# 229         East Asia & Pacific (IDA & IBRD)
# 230       Europe & Central Asia (IDA & IBRD)
# 235   Latin America & Caribbean (IDA & IBRD)
# 237  Middle East & North Africa (IDA & IBRD)
# 240          Sub-Saharan Africa (IDA & IBRD)
# ...

# %%
merged.drop(['Unnamed: 67', 'Unnamed: 5','TableName'], axis=1, inplace=True)

# %%
merged
# Out:
#                     Country Name Country Code         1960         1961  \
# 0                          Aruba          ABW      54608.0      55811.0
# 1    Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                    Afghanistan          AFG    8622466.0    8790140.0
# 3     Africa Western and Central          AFW   97256290.0   99314028.0
# 4                         Angola          AGO    5357195.0    5441333.0
# ..                           ...          ...          ...          ...
# 260                       Kosovo          XKX     947000.0     966000.0
# 261                  Yemen, Rep.          YEM    5542459.0    5646668.0
# 262                 South Africa          ZAF   16520441.0   16989464.0
# 263                       Zambia          ZMB    3119430.0    3219451.0
# 264                     Zimbabwe          ZWE    3806310.0    3925952.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %% [markdown]
# **Distribution of Region**

# %%
region_count=merged['Region'].value_counts()
region_count
# Out:
# Europe & Central Asia         58
# Sub-Saharan Africa            48
# Latin America & Caribbean     42
# East Asia & Pacific           37
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: Region, dtype: int64

# %%
x=range(len(region_count.index))
x
# Out:
# range(0, 7)

# %%
plt.figure(figsize=(16,9))
plt.bar(region_count.index, region_count.values)
plt.title('Distribution of Regions')
plt.xlabel('Regions')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# **Distribution of Income**

# %%
income_count = merged['IncomeGroup'].value_counts()
income_count
# Out:
# High income            82
# Lower middle income    54
# Upper middle income    54
# Low income             26
# Name: IncomeGroup, dtype: int64

# %%
y = range(len(income_count.index))
y
# Out:
# range(0, 4)

# %%
plt.figure(figsize=(16,9))
plt.bar(income_count.index, income_count.values)
plt.title('Distribution of Income')
plt.xlabel('Income')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
